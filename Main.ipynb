# %%
# Importation de TensorFlow pour la construction et l'entraînement des réseaux de neurones
import tensorflow as tf
# Importation de Matplotlib pour la visualisation graphique des données et résultats
import matplotlib.pyplot as plt
# Importation de NumPy pour la manipulation d'arrays et opérations mathématiques
import numpy as np
# Importation du module OS pour les opérations sur les fichiers et dossiers
import os
# Importation de Seaborn pour des visualisations statistiques avancées
import seaborn as sns
# Importation de Pandas pour la manipulation de données tabulaires
import pandas as pd
# Importation de Scikit-learn pour les algorithmes de machine learning classiques
import sklearn as sk

# %%
# Définition du chemin vers le dossier contenant les images d'entraînement
train_dir = "Data/Training"
# Définition du chemin vers le dossier contenant les images de test
test_dir = "Data/Testing"

# Parcours de toutes les classes (glioma, meningioma, notumor, pituitary) dans le dossier d'entraînement
for classe in os.listdir(train_dir):
    # Affichage du nom de la classe et du nombre d'images qu'elle contient
    print(classe, len(os.listdir(os.path.join(train_dir, classe))))
# Out:
# glioma 1400
# meningioma 1400
# notumor 1400
# pituitary 1400

# %%
# Définition de la taille cible pour redimensionner toutes les images (224x224 pixels)
IMG_SIZE = (224, 224)
# Définition de la taille des lots (batches) pour l'entraînement (32 images par lot)
BATCH_SIZE = 32
# Définition de la graine aléatoire pour assurer la reproductibilité des résultats
SEED = 42

# %%
# Création du dataset d'entraînement à partir des images du dossier train_dir
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,  # Dossier source contenant les images d'entraînement
    validation_split=0.2,  # Réservation de 20% des données pour la validation
    subset="training",  # Sélection de la portion "entraînement" (80%)
    seed=SEED,  # Graine aléatoire pour la reproductibilité du split
    image_size=IMG_SIZE,  # Redimensionnement de toutes les images à 224x224
    batch_size=BATCH_SIZE  # Regroupement des images en lots de 32
)

# Création du dataset de validation à partir du même dossier
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,  # Même dossier source que pour l'entraînement
    validation_split=0.2,  # Même proportion de split (20% pour validation)
    subset="validation",  # Sélection de la portion "validation" (20%)
    seed=SEED,  # Même graine pour cohérence avec le split d'entraînement
    image_size=IMG_SIZE,  # Redimensionnement identique à 224x224
    batch_size=BATCH_SIZE  # Même taille de lots (32 images)
)
# Out:
# Found 5600 files belonging to 4 classes.
# Using 4480 files for training.
# Found 5600 files belonging to 4 classes.
# Using 1120 files for validation.

# %%
# Création du dataset de test à partir des images du dossier test_dir
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,  # Dossier source contenant les images de test
    image_size=IMG_SIZE,  # Redimensionnement des images à 224x224 (même taille que train/val)
    batch_size=BATCH_SIZE,  # Regroupement en lots de 32 images
    shuffle=False  # Pas de mélange pour maintenir l'ordre des images lors de l'évaluation
)
# Out:
# Found 1600 files belonging to 4 classes.

# %%
# Affichage des noms des classes détectées automatiquement (glioma, meningioma, notumor, pituitary)
print(train_ds.class_names)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
# Création d'une couche de normalisation qui divise les valeurs de pixels par 255
# Cela transforme les valeurs de [0, 255] vers [0, 1] pour faciliter l'apprentissage
normalization_layer = tf.keras.layers.Rescaling(1./255)

# Application de la normalisation à toutes les images du dataset d'entraînement
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
# Application de la normalisation à toutes les images du dataset de validation
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
# Application de la normalisation à toutes les images du dataset de test
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
# Création d'un pipeline d'augmentation de données pour enrichir le dataset d'entraînement
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),  # Retournement horizontal aléatoire des images
    tf.keras.layers.RandomRotation(0.1),  # Rotation aléatoire jusqu'à 10% (36 degrés)
    tf.keras.layers.RandomZoom(0.1),  # Zoom aléatoire jusqu'à 10% pour varier l'échelle
])

# %%
# Application de l'augmentation de données au dataset d'entraînement
train_ds = train_ds.map(
    # Transformation des images avec augmentation aléatoire (seulement pendant l'entraînement)
    lambda x, y: (data_augmentation(x, training=True), y)
)

# %%
# Configuration de l'auto-tuning pour optimiser les performances de chargement des données
AUTOTUNE = tf.data.AUTOTUNE

# Activation du prefetching pour le dataset d'entraînement (charge les données en arrière-plan)
train_ds = train_ds.prefetch(AUTOTUNE)
# Activation du prefetching pour le dataset de validation
val_ds = val_ds.prefetch(AUTOTUNE)
# Activation du prefetching pour le dataset de test
test_ds = test_ds.prefetch(AUTOTUNE)

# %% [markdown]
# ## Tache 2

# %%
# Chargement du modèle pré-entraîné ResNet50 pour l'extraction de caractéristiques
base_model = tf.keras.applications.ResNet50(
    weights="imagenet",  # Utilisation des poids pré-entraînés sur ImageNet
    include_top=False,  # Exclusion de la couche de classification finale (1000 classes ImageNet)
    pooling="avg",  # Application d'un pooling moyen global pour réduire à un vecteur de features
    input_shape=(224,224,3)  # Forme d'entrée attendue: images 224x224 avec 3 canaux (RGB)
)

# %%
# Fonction pour extraire les caractéristiques (features) d'un dataset avec le modèle pré-entraîné
def extract_features(dataset):
    # Initialisation de la liste pour stocker les features extraites
    X = []
    # Initialisation de la liste pour stocker les labels correspondants
    y = []
    
    # Parcours de tous les lots (batches) d'images et labels du dataset
    for images, labels in dataset:
        # Extraction des features de chaque lot d'images via ResNet50 (vecteurs 2048-d)
        features = base_model.predict(images, verbose=0)
        # Ajout des features extraites à la liste X
        X.append(features)
        # Conversion et ajout des labels TensorFlow en numpy arrays
        y.append(labels.numpy())
        
    # Empilement vertical de tous les features pour créer une matrice unique
    # Concaténation de tous les labels pour créer un vecteur unique
    return np.vstack(X), np.concatenate(y)

# %%
# Extraction des features du dataset d'entraînement (X_train) et ses labels (y_train)
X_train, y_train = extract_features(train_ds)
# Extraction des features du dataset de validation (X_val) et ses labels (y_val)
X_val, y_val = extract_features(val_ds)
# Extraction des features du dataset de test (X_test) et ses labels (y_test)
X_test, y_test = extract_features(test_ds)

# %%
# Importation du modèle de régression logistique de scikit-learn
from sklearn.linear_model import LogisticRegression

# scikit-learn récent: l'argument multi_class est supprimé;
# avec solver='lbfgs' et >2 classes, l'approche multinomiale est utilisée.
log_reg = LogisticRegression(
    max_iter=2000,
    solver="lbfgs"
)

# Entraînement du modèle sur les features extraites et leurs labels
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
# Importation du module de calibration de probabilités de scikit-learn
from sklearn.calibration import CalibratedClassifierCV

# Création d'un modèle calibré pour améliorer la fiabilité des probabilités prédites
calibrated_model = CalibratedClassifierCV(
    log_reg,  # Modèle de base à calibrer (régression logistique entraînée)
    method="sigmoid",   # Utilisation de la méthode "Platt scaling" pour la calibration
    cv=5  # Validation croisée à 5 plis pour calibrer le modèle
)

# Calibration du modèle sur le dataset de validation
calibrated_model.fit(X_val, y_val)
# Out:
# CalibratedClassifierCV(cv=5, estimator=LogisticRegression(max_iter=2000))

# %%
# Prédiction des probabilités pour chaque classe sur le dataset de test
probas = calibrated_model.predict_proba(X_test)

# Importation de NumPy pour les calculs
import numpy as np

# Calcul de la probabilité maximale pour chaque prédiction (confiance du modèle)
max_probs = np.max(probas, axis=1)

# Identification des prédictions incertaines (confiance < 70%)
uncertain_mask = max_probs < 0.7
# Comptage du nombre de prédictions incertaines
nb_uncertain = np.sum(uncertain_mask)

# Affichage du nombre de prédictions incertaines
print("Nombre de prédictions incertaines :", nb_uncertain)
# Out:
# Nombre de prédictions incertaines : 996

# %%
# Importation de Matplotlib pour visualiser les résultats
import matplotlib.pyplot as plt

# Création d'un histogramme des probabilités maximales avec 20 barres
plt.hist(max_probs, bins=20)
# Ajout d'une ligne verticale en pointillés à 0.7 pour marquer le seuil d'incertitude
plt.axvline(0.7, linestyle="--")
# Ajout d'un titre au graphique
plt.title("Distribution des probabilités maximales")
# Ajout d'une étiquette pour l'axe des x
plt.xlabel("Confiance du modèle")
# Ajout d'une étiquette pour l'axe des y
plt.ylabel("Nombre d'images")
# Affichage du graphique
plt.show()

# %%
# Importation de TensorFlow pour construire le réseau de neurones
import tensorflow as tf

# Construction d'un réseau de neurones multicouches (MLP) séquentiel
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2048,)),  # Couche d'entrée acceptant des vecteurs de 2048 dimensions
    tf.keras.layers.Dense(512, activation='relu'),  # Première couche dense avec 512 neurones et activation ReLU
    tf.keras.layers.Dropout(0.5),  # Dropout de 50% pour régulariser et éviter le surapprentissage
    tf.keras.layers.Dense(128, activation='relu'),  # Deuxième couche dense avec 128 neurones et activation ReLU
    tf.keras.layers.Dropout(0.3),  # Dropout de 30% pour régularisation supplémentaire
    tf.keras.layers.Dense(4, activation='softmax')  # Couche de sortie avec 4 neurones (4 classes) et activation softmax
])


# Compilation du modèle avec les paramètres d'entraînement
model.compile(
    optimizer='adam',  # Utilisation de l'optimiseur Adam pour l'ajustement des poids
    loss='sparse_categorical_crossentropy',  # Fonction de perte pour classification multi-classes
    metrics=['accuracy']  # Métrique d'évaluation: précision (accuracy)
)

# Affichage de l'architecture du modèle (nombre de paramètres, couches, etc.)
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 4)              │           516 │
# ...

# %%
# Entraînement du modèle MLP sur les features extraites
history = model.fit(
    X_train, y_train,  # Données d'entraînement (features et labels)
    validation_data=(X_val, y_val),  # Données de validation pour surveiller la performance
    epochs=30,  # Nombre d'époques d'entraînement (30 passages complets sur les données)
    batch_size=32  # Taille des lots pour l'entraînement (32 échantillons par batch)
)
# Out:
# Epoch 1/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.3714 - loss: 1.3248 - val_accuracy: 0.4563 - val_loss: 1.1233
# Epoch 2/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4417 - loss: 1.1733 - val_accuracy: 0.4446 - val_loss: 1.1589
# Epoch 3/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4641 - loss: 1.1438 - val_accuracy: 0.4268 - val_loss: 1.1748
# Epoch 4/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4815 - loss: 1.1156 - val_accuracy: 0.4938 - val_loss: 1.1193
# Epoch 5/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5065 - loss: 1.0792 - val_accuracy: 0.6241 - val_loss: 1.0111
# Epoch 6/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5165 - loss: 1.0767 - val_accuracy: 0.5607 - val_loss: 1.0662
# Epoch 7/30
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5413 - loss: 1.0454 - val_accuracy: 0.5545 - val_loss: 1.0529
# Epoch 8/30
# ...

# %%
# Prédiction probabiliste avec le MLP sur le jeu de test
mlp_probas = model.predict(X_test, verbose=0)
# Probabilité maximale (confiance) pour chaque prédiction du MLP
mlp_max_probs = np.max(mlp_probas, axis=1)

# Prédictions incertaines du MLP (confiance < 70%)
mlp_uncertain_mask = mlp_max_probs < 0.7
mlp_nb_uncertain = int(np.sum(mlp_uncertain_mask))

# Affichage du niveau d'incertitude du MLP
print("Nombre de prédictions incertaines (MLP) :", mlp_nb_uncertain)
print("Pourcentage (MLP) :", mlp_nb_uncertain / len(mlp_max_probs) * 100, "%")
# Out:
# Nombre de prédictions incertaines (MLP) : 1246
# Pourcentage (MLP) : 77.875 %

# %%
# Importation de Matplotlib pour la visualisation
import matplotlib.pyplot as plt

# Création d'un histogramme des probabilités maximales du MLP avec 20 barres
plt.hist(mlp_max_probs, bins=20)
# Ligne verticale en pointillés à 0.7 pour marquer le seuil d'incertitude
plt.axvline(0.7, linestyle="--")
# Titre du graphique spécifique au MLP
plt.title("Distribution des probabilités max (MLP)")
# Étiquette de l'axe des x
plt.xlabel("Confiance")
# Étiquette de l'axe des y
plt.ylabel("Nombre d'images")
# Affichage du graphique
plt.show()

# %%
# Importation du module de métriques de classification de scikit-learn
from sklearn.metrics import classification_report

# Prédictions finales du MLP (classe avec probabilité maximale)
y_pred_mlp = np.argmax(mlp_probas, axis=1)

# Affichage du rapport de classification MLP (précision, rappel, f1-score)
print(classification_report(y_test, y_pred_mlp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.58      0.59       400
#            1       0.66      0.21      0.32       400
#            2       0.70      0.83      0.76       400
#            3       0.59      0.90      0.71       400
#
#     accuracy                           0.63      1600
#    macro avg       0.64      0.63      0.60      1600
# weighted avg       0.64      0.63      0.60      1600

# %%
# Importation des bibliothèques nécessaires
import tensorflow as tf
import numpy as np
from sklearn.metrics import classification_report




# Recréation du dataset d'entraînement brut (sans augmentation) pour le CNN
raw_train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,  # Dossier source des images d'entraînement
    validation_split=0.2,  # Réservation de 20% pour la validation
    subset="training",  # Sélection de la portion entraînement (80%)
    seed=SEED,  # Graine pour reproductibilité
    image_size=IMG_SIZE,  # Redimensionnement à 224x224
    batch_size=BATCH_SIZE  # Lots de 32 images
)

# Recréation du dataset de validation brut pour le CNN
raw_val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,  # Même dossier source
    validation_split=0.2,  # Même proportion de split
    subset="validation",  # Sélection de la portion validation (20%)
    seed=SEED,  # Même graine pour cohérence
    image_size=IMG_SIZE,  # Même taille d'images
    batch_size=BATCH_SIZE  # Même taille de lots
)

# Récupération des noms de classes
class_names = raw_train_ds.class_names
# Calcul du nombre de classes (4: glioma, meningioma, notumor, pituitary)
num_classes = len(class_names)
print("Classes :", class_names)


# Application du prefetching pour optimiser les performances de chargement
train_ds = raw_train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = raw_val_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# Found 5600 files belonging to 4 classes.
# Using 4480 files for training.
# Found 5600 files belonging to 4 classes.
# Using 1120 files for validation.
# Classes : ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
# Définition de la couche d'entrée pour des images 224x224 RGB
inputs = tf.keras.Input(shape=(224, 224, 3))
# Normalisation des pixels de [0, 255] vers [0, 1]
x = tf.keras.layers.Rescaling(1./255)(inputs)
# Première couche de convolution: 32 filtres 3x3 avec activation ReLU
x = tf.keras.layers.Conv2D(32, (3,3), activation='relu')(x)
# Première couche de max pooling pour réduire la dimension spatiale
x = tf.keras.layers.MaxPooling2D()(x)
# Deuxième couche de convolution: 64 filtres 3x3 avec activation ReLU
x = tf.keras.layers.Conv2D(64, (3,3), activation='relu')(x)
# Deuxième couche de max pooling
x = tf.keras.layers.MaxPooling2D()(x)
# Aplatissement des feature maps 2D en un vecteur 1D
x = tf.keras.layers.Flatten()(x)
# Couche dense avec 128 neurones et activation ReLU (couche d'extraction de features)
x = tf.keras.layers.Dense(128, activation='relu', name='dense_128')(x)
# Couche de sortie avec autant de neurones que de classes (4), sans activation (logits)
outputs = tf.keras.layers.Dense(num_classes)(x)

# Création du modèle CNN final reliant les entrées aux sorties
cnn = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
# Compilation du modèle CNN avec les paramètres d'entraînement
cnn.compile(
    optimizer='adam',  # Optimiseur Adam pour l'ajustement des poids
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),  # Fonction de perte (from_logits=True car pas de softmax en sortie)
    metrics=['accuracy']  # Métrique de précision pour l'évaluation
)
# Entraînement du modèle CNN sur 5 époques avec validation
cnn.fit(train_ds, validation_data=val_ds, epochs=5)
# Out:
# Epoch 1/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 41s 283ms/step - accuracy: 0.7060 - loss: 0.8042 - val_accuracy: 0.8446 - val_loss: 0.4039
# Epoch 2/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 47s 339ms/step - accuracy: 0.9105 - loss: 0.2435 - val_accuracy: 0.9009 - val_loss: 0.2817
# Epoch 3/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 52s 371ms/step - accuracy: 0.9670 - loss: 0.0934 - val_accuracy: 0.9080 - val_loss: 0.3013
# Epoch 4/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 47s 334ms/step - accuracy: 0.9848 - loss: 0.0421 - val_accuracy: 0.9312 - val_loss: 0.2756
# Epoch 5/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 60s 427ms/step - accuracy: 0.9935 - loss: 0.0230 - val_accuracy: 0.9062 - val_loss: 0.3794

# %%
# --- Collecte des logits et labels de validation ---
# Initialisation de la liste pour stocker les logits (sorties brutes du réseau)
logits_list = []
# Initialisation de la liste pour stocker les labels réels
labels_list = []

# Parcours de tous les lots du dataset de validation
for images, labels in val_ds:
    # Obtention des logits (prédictions brutes) pour chaque lot d'images
    logits = cnn(images, training=False)
    # Ajout des logits convertis en numpy arrays à la liste
    logits_list.append(logits.numpy())
    # Ajout des labels convertis en numpy arrays à la liste
    labels_list.append(labels.numpy())

# Empilement vertical de tous les logits en une seule matrice
logits_all = np.vstack(logits_list)
# Concaténation horizontale de tous les labels en un seul vecteur
labels_all = np.hstack(labels_list)

# %%
# --- Temperature Scaling pour calibrer les probabilités ---
# Initialisation de la température à 1.0 (valeur neutre)
T = tf.Variable(1.0, dtype=tf.float32)

# Création de l'optimiseur Adam avec un taux d'apprentissage de 0.01
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

# Boucle d'optimisation sur 100 itérations
for step in range(100):
    # Enregistrement des opérations pour calculer les gradients
    with tf.GradientTape() as tape:
        # Division des logits par la température pour les calibrer
        scaled_logits = logits_all / T
        # Calcul de la perte d'entropie croisée avec les logits calibrés
        loss = tf.reduce_mean(
            tf.nn.sparse_softmax_cross_entropy_with_logits(
                labels=labels_all,  # Labels réels
                logits=scaled_logits  # Logits calibrés
            )
        )
    # Calcul des gradients de la perte par rapport à la température
    grads = tape.gradient(loss, [T])
    # Mise à jour de la température avec les gradients
    optimizer.apply_gradients(zip(grads, [T]))

# Affichage de la température finale optimisée
print("Température optimale :", T.numpy())
# Out:
# Température optimale : 1.7010989

# %%
# --- Calcul des probabilités calibrées ---
# Application de la température optimale aux logits pour les calibrer
scaled_logits = logits_all / T.numpy()
# Conversion des logits calibrés en probabilités via la fonction softmax
probas = tf.nn.softmax(scaled_logits, axis=1).numpy()
# Obtention des prédictions finales (classe avec la probabilité maximale)
y_pred = np.argmax(probas, axis=1)

# Affichage du rapport de classification détaillé (précision, rappel, f1-score)
print(classification_report(labels_all, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.89       260
#            1       0.84      0.81      0.82       275
#            2       0.96      0.98      0.97       300
#            3       0.98      0.90      0.94       285
#
#     accuracy                           0.91      1120
#    macro avg       0.91      0.91      0.90      1120
# weighted avg       0.91      0.91      0.91      1120

# %%
# --- Détection des prédictions incertaines ---
# Récupération de la probabilité maximale pour chaque prédiction
max_probs = np.max(probas, axis=1)
# Identification des indices des prédictions avec une confiance < 70%
uncertain_idx = np.where(max_probs < 0.7)[0]

# Affichage du nombre de prédictions incertaines
print("Nombre de prédictions incertaines :", len(uncertain_idx))
# Calcul et affichage du pourcentage de prédictions incertaines
print("Pourcentage d'incertitude :", len(uncertain_idx)/len(probas)*100, "%")
# Out:
# Nombre de prédictions incertaines : 111
# Pourcentage d'incertitude : 9.910714285714285 %

# %%
# Passage d'un batch de validation à travers le CNN pour initialiser les poids
for images, _ in val_ds.take(1):
    _ = cnn(images, training=False)  # Exécution du modèle en mode inférence

# Création d'un modèle intermédiaire pour extraire les activations de l'avant-dernière couche
activation_model = tf.keras.Model(inputs=cnn.input, outputs=cnn.layers[-2].output)


# Initialisation de la liste pour stocker les activations
activations_list = []
# Parcours de tous les lots du dataset de validation
for images, _ in val_ds:
    # Extraction des activations de l'avant-dernière couche pour chaque lot
    act = activation_model(images, training=False)
    # Ajout des activations converties en numpy à la liste
    activations_list.append(act.numpy())

# Empilement vertical de toutes les activations en une seule matrice
activations = np.vstack(activations_list)


# Sauvegarde des activations dans un fichier .npy
np.save("cnn_activations.npy", activations)
# Sauvegarde des probabilités calibrées dans un fichier .npy
np.save("cnn_probabilities.npy", probas)
print("Activations et probabilités sauvegardées.")
# Out:
# Activations et probabilités sauvegardées.

# %%
# Définition du seuil de confiance haute pour validation automatique (85%)
SEUIL_HAUTE_CONFIANCE = 0.85
# Définition du seuil de confiance moyenne pour révision par junior (65%)
SEUIL_CONFIANCE_MOYENNE = 0.65
# Définition du seuil de confiance faible pour révision par senior (50%)
SEUIL_CONFIANCE_FAIBLE = 0.50

# Fonction pour déterminer le niveau d'urgence selon la classe prédite
def determiner_urgence(classe_predite):
    # Si la classe contient le mot "tumeur", urgence élevée (24h)
    if "tumeur" in classe_predite.lower():
        return "Elevee (24h)"
    # Sinon, urgence normale (48h)
    else:
        return "Normale (48h)"

# %%
# Initialisation des listes pour stocker les résultats du système de décision
decisions = []  # Liste pour stocker les décisions prises
actions = []  # Liste pour stocker les actions recommandées
priorites = []  # Liste pour stocker les niveaux de priorité

# Parcours de toutes les prédictions
for i in range(len(y_pred)):
    # Obtention du nom de la classe prédite
    classe_predite = class_names[y_pred[i]]
    # Obtention de la probabilité maximale (confiance) pour cette prédiction
    max_probabilite = np.max(probas[i])
    
    # --- Logique principale de décision basée sur la confiance ---
    if max_probabilite >= SEUIL_HAUTE_CONFIANCE:  # Confiance ≥ 85%
        # Haute confiance: diagnostic automatique validé
        decision = "Diagnostic automatique valide"
        # Action: envoi direct du rapport au médecin traitant
        action = "Rapport envoyé au médecin traitant"
        # Priorité déterminée selon la classe (tumeur = urgent)
        priorite = determiner_urgence(classe_predite)
    elif max_probabilite >= SEUIL_CONFIANCE_MOYENNE:  # Confiance entre 65% et 85%
        # Confiance moyenne: diagnostic probable nécessitant révision
        decision = "Diagnostic probable - Révision recommandée"
        # Action: validation par un radiologue junior
        action = "Validation par radiologue junior"
        # Priorité normale (48h)
        priorite = "Normale (48h)"
    elif max_probabilite >= SEUIL_CONFIANCE_FAIBLE:  # Confiance entre 50% et 65%
        # Confiance faible: cas incertain
        decision = "Cas incertain"
        # Action: révision par un radiologue senior (expertise)
        action = "Révision par radiologue senior"
        # Priorité élevée (24h)
        priorite = "Élevée (24h)"
    else:  # Confiance < 50%
        # Confiance très faible: incertitude élevée
        decision = "Incertitude élevée"
        # Action: double lecture obligatoire + examen complémentaire (IRM)
        action = "Double lecture obligatoire + IRM complémentaire"
        # Priorité urgente (12h)
        priorite = "Urgente (12h)"
    
    # --- Gestion spécifique pour minimiser les faux négatifs (sécurité patient) ---
    classe_norm = classe_predite.lower().replace(" ", "").replace("_", "")
    if classe_norm in ["pasdetumeur", "notumor", "notumeur"]:
        # Seuil très élevé (95%) pour valider l'absence de tumeur sans vérification
        if max_probabilite < 0.95:
            # Action: vérification obligatoire pour éviter les faux négatifs dangereux
            action = "Vérification obligatoire (risque faux négatif)"
    
    # Stockage des résultats pour cette prédiction
    decisions.append(decision)
    actions.append(action)
    priorites.append(priorite)

# %%
# --- Affichage des résultats pour les 10 premiers cas ---
# Boucle pour afficher les 10 premières prédictions (ou moins si moins de 10 prédictions)
for i in range(min(10, len(y_pred))):
    # Affichage du numéro d'image
    print(f"Image {i+1}:")
    # Affichage de la classe prédite par le modèle
    print(f"  Classe prédite : {class_names[y_pred[i]]}")
    # Affichage de la probabilité maximale (confiance) avec 2 décimales
    print(f"  Probabilité max : {np.max(probas[i]):.2f}")
    # Affichage de la décision prise par le système
    print(f"  Décision : {decisions[i]}")
    # Affichage de l'action recommandée
    print(f"  Action : {actions[i]}")
    # Affichage du niveau de priorité assigné
    print(f"  Priorité : {priorites[i]}")
    # Séparateur visuel entre chaque cas
    print("-"*40)
# Out:
# Image 1:
#   Classe prédite : glioma
#   Probabilité max : 0.99
#   Décision : Diagnostic automatique valide
#   Action : Rapport envoyé au médecin traitant
#   Priorité : Normale (48h)
# ----------------------------------------
# Image 2:
#   Classe prédite : notumor
#   Probabilité max : 0.91
#   Décision : Diagnostic automatique valide
#   Action : Vérification obligatoire (risque faux négatif)
#   Priorité : Normale (48h)
# ----------------------------------------
# Image 3:
#   Classe prédite : meningioma
#   Probabilité max : 0.60
#   Décision : Cas incertain
#   Action : Révision par radiologue senior
#   Priorité : Élevée (24h)
# ----------------------------------------
# Image 4:
#   Classe prédite : pituitary
#   Probabilité max : 0.98
#   Décision : Diagnostic automatique valide
#   Action : Rapport envoyé au médecin traitant
#   Priorité : Normale (48h)
# ----------------------------------------
# Image 5:
#   Classe prédite : glioma
#   Probabilité max : 0.82
# ...

# %%
from datetime import datetime
import os
import unicodedata
import numpy as np


def normaliser_code_classe(nom_classe):
    brut = unicodedata.normalize("NFKD", str(nom_classe)).encode("ascii", "ignore").decode("ascii")
    brut = brut.lower().replace(" ", "").replace("_", "").replace("-", "")
    correspondances = {
        "glioma": "glioma",
        "gliome": "glioma",
        "meningioma": "meningioma",
        "meningiome": "meningioma",
        "pituitary": "pituitary",
        "pituitaire": "pituitary",
        "notumor": "notumor",
        "notumeur": "notumor",
        "pasdetumeur": "notumor",
        "aucunetumeur": "notumor",
    }
    return correspondances.get(brut, brut)


NOMS_CLASSES_FR = {
    "glioma": "Gliome",
    "meningioma": "Meningiome",
    "pituitary": "Tumeur pituitaire",
    "notumor": "Pas de tumeur",
}
ORDRE_AFFICHAGE_CLASSES = ["glioma", "meningioma", "pituitary", "notumor"]


def niveau_certitude(confiance):
    if confiance >= SEUIL_HAUTE_CONFIANCE:
        return "ELEVE [OK]"
    if confiance >= SEUIL_CONFIANCE_MOYENNE:
        return "MOYEN [~]"
    if confiance >= SEUIL_CONFIANCE_FAIBLE:
        return "FAIBLE [!]"
    return "TRES FAIBLE [X]"


def recommandations_cliniques(code_classe, confiance):
    if code_classe == "glioma":
        if confiance >= SEUIL_HAUTE_CONFIANCE:
            return (
                "Gliome detecte (haute confiance)",
                "Referer immediatement en oncologie",
                "[!] URGENT - Prise en charge sous 12h",
                "Optionnelle (validation finale)",
                ["Tumeur maligne suspectee", "IRM de controle recommandee"],
            )
        if confiance >= SEUIL_CONFIANCE_MOYENNE:
            return (
                "Gliome probable (confiance moyenne)",
                "Validation par neuro-oncologie",
                "[!] ELEVEE - Reevaluation sous 24h",
                "Obligatoire",
                ["Risque tumoral a confirmer", "IRM de controle recommandee"],
            )
        return (
            "Suspicion de gliome (a confirmer)",
            "Double lecture + examens complementaires",
            "[!] ELEVEE - Reevaluation sous 24h",
            "Obligatoire",
            ["Incertitude diagnostique", "IRM de controle recommandee"],
        )

    if code_classe == "meningioma":
        if confiance >= SEUIL_HAUTE_CONFIANCE:
            return (
                "Meningiome detecte (haute confiance)",
                "Referer en neurochirurgie",
                "[!] ELEVEE - Avis specialise sous 24h",
                "Optionnelle (validation finale)",
                ["Compression locale possible", "Suivi neurologique recommande"],
            )
        return (
            "Meningiome suspecte",
            "Validation par radiologue senior",
            "[~] MODEREE - Reevaluation sous 48h",
            "Obligatoire",
            ["Verifier effet de masse", "IRM de controle recommandee"],
        )

    if code_classe == "pituitary":
        if confiance >= SEUIL_HAUTE_CONFIANCE:
            return (
                "Tumeur pituitaire detectee (haute confiance)",
                "Referer en endocrinologie et neurochirurgie",
                "[!] ELEVEE - Evaluation sous 24h",
                "Optionnelle (validation finale)",
                ["Trouble hormonal possible", "Bilan endocrinien recommande"],
            )
        return (
            "Tumeur pituitaire suspectee",
            "Validation specialisee endocrino-radiologique",
            "[~] MODEREE - Reevaluation sous 48h",
            "Obligatoire",
            ["Verifier l'axe hypothalamo-hypophysaire", "IRM de controle recommandee"],
        )

    if code_classe == "notumor":
        if confiance >= 0.95:
            return (
                "Absence de tumeur probable (tres haute confiance)",
                "Suivi clinique standard",
                "[OK] FAIBLE - Controle de routine",
                "Optionnelle",
                ["Aucune lesion evidente", "Surveillance clinique recommandee"],
            )
        if confiance >= SEUIL_HAUTE_CONFIANCE:
            return (
                "Pas de tumeur detectee (haute confiance)",
                "Validation radiologique avant cloture",
                "[~] MODEREE - Validation sous 48h",
                "Recommandee",
                ["Verifier qualite des images", "Risque faible de faux negatif"],
            )
        return (
            "Absence de tumeur non confirmee",
            "Relecture obligatoire + examen complementaire si besoin",
            "[!] ELEVEE - Reevaluation sous 24h",
            "Obligatoire",
            ["Risque de faux negatif", "IRM de controle recommandee"],
        )

    return (
        f"Classe non standard detectee: {code_classe}",
        "Validation humaine obligatoire",
        "[!] ELEVEE - Reevaluation sous 24h",
        "Obligatoire",
        ["Verifier le mapping des classes", "Relecture radiologique recommandee"],
    )


def generer_rapport_patient(patient_id, date_rapport, probabilites_patient, classe_predite_code, index_par_code):
    confiance = float(np.max(probabilites_patient))
    classe_fr = NOMS_CLASSES_FR.get(classe_predite_code, classe_predite_code.title())
    certitude = niveau_certitude(confiance)
    diagnostic, action, priorite, revision_humaine, alertes = recommandations_cliniques(classe_predite_code, confiance)

    lignes = [
        "Rapport Automatise",
        "========================================",
        "RAPPORT D'AIDE A LA DECISION",
        "========================================",
        f"Patient ID: {patient_id} Date: {date_rapport}",
        "PREDICTION PRINCIPALE",
        "---------------------",
        f"Classe: {classe_fr}",
        f"Confiance: {confiance * 100:.1f}%",
        f"Niveau de certitude: {certitude}",
        "SCORES PAR CLASSE",
        "-----------------",
    ]

    for code in ORDRE_AFFICHAGE_CLASSES:
        idx = index_par_code.get(code)
        score = float(probabilites_patient[idx]) if idx is not None else 0.0
        lignes.append(f"• {NOMS_CLASSES_FR[code]}: {score * 100:.1f}%")

    lignes.extend(
        [
            "RECOMMANDATIONS CLINIQUES",
            "--------------------------",
            f"Diagnostic: {diagnostic}",
            f"Action: {action}",
            f"Priorite: {priorite}",
            f"Revision humaine: {revision_humaine}",
            "ELEMENTS D'ATTENTION",
            "---------------------",
        ]
    )

    for alerte in alertes:
        lignes.append(f"• {alerte}")

    lignes.append("========================================")
    return "\n".join(lignes)


index_par_code = {}
for idx, nom_classe in enumerate(class_names):
    code = normaliser_code_classe(nom_classe)
    if code not in index_par_code:
        index_par_code[code] = idx

if len(y_pred) != len(probas):
    raise ValueError("Incoherence detectee: len(y_pred) doit etre egal a len(probas).")

date_rapport = datetime.now().strftime("%d/%m/%Y")
dossier_rapports = "Rapports_Automatises"
os.makedirs(dossier_rapports, exist_ok=True)

rapports_par_patient = {}
for i in range(len(y_pred)):
    if i >= 20 :
        break
    patient_id = f"P_{i + 1:05d}"
    code_pred = normaliser_code_classe(class_names[y_pred[i]])

    rapport = generer_rapport_patient(
        patient_id=patient_id,
        date_rapport=date_rapport,
        probabilites_patient=probas[i],
        classe_predite_code=code_pred,
        index_par_code=index_par_code,
    )

    rapports_par_patient[patient_id] = rapport
    chemin_rapport = os.path.join(dossier_rapports, f"{patient_id}.txt")
    with open(chemin_rapport, "w", encoding="utf-8") as fichier:
        fichier.write(rapport)

print(f"{len(rapports_par_patient)} rapports generes dans le dossier '{dossier_rapports}'.")
if rapports_par_patient:
    premier_id = next(iter(rapports_par_patient))
    print("\nExemple de rapport (premier patient):\n")
    print(rapports_par_patient[premier_id])
# Out:
# 20 rapports generes dans le dossier 'Rapports_Automatises'.
#
# Exemple de rapport (premier patient):
#
# Rapport Automatise
# ...
# RAPPORT D'AIDE A LA DECISION
# ...
# Patient ID: P_00001 Date: 05/03/2026
# PREDICTION PRINCIPALE
# ---------------------
# Classe: Gliome
# Confiance: 99.0%
# Niveau de certitude: ELEVE [OK]
# SCORES PAR CLASSE
# -----------------
# • Gliome: 99.0%
# • Meningiome: 1.0%
# • Tumeur pituitaire: 0.0%
# • Pas de tumeur: 0.0%
# RECOMMANDATIONS CLINIQUES
# --------------------------
# Diagnostic: Gliome detecte (haute confiance)
# Action: Referer immediatement en oncologie
# Priorite: [!] URGENT - Prise en charge sous 12h
# Revision humaine: Optionnelle (validation finale)
# ELEMENTS D'ATTENTION
# ---------------------
# • Tumeur maligne suspectee
# • IRM de controle recommandee
# ...

# %%
# ===============================
# ETAPE 7 - ANALYSE DE PERFORMANCE DU SAD
# ===============================

# Verification de base : y_pred et probas doivent etre alignes
if len(y_pred) != len(probas):
    raise ValueError("Les dimensions de y_pred et probas doivent etre identiques.")

# Selection automatique de la verite terrain coherente avec le pipeline actif
if "labels_all" in globals() and len(labels_all) == len(y_pred):
    y_true_eval = np.asarray(labels_all, dtype=int)
    source_verite = "labels_all (pipeline CNN calibre)"
elif "y_test" in globals() and len(y_test) == len(y_pred):
    y_true_eval = np.asarray(y_test, dtype=int)
    source_verite = "y_test (dataset de test)"
else:
    raise ValueError(
        "Impossible d'aligner les labels de verite avec y_pred. "
        "Verifiez que labels_all (ou y_test) correspond aux predictions courantes."
    )

y_pred_eval = np.asarray(y_pred, dtype=int)

# Confiance max par patient
max_probs = np.max(probas, axis=1)

# Codes classes predite / vraie (normalises)
codes_pred = np.array([normaliser_code_classe(class_names[int(idx)]) for idx in y_pred_eval])
codes_true = np.array([normaliser_code_classe(class_names[int(idx)]) for idx in y_true_eval])

# 1) Taux de couverture automatique
# Cas auto: confiance >= 0.85, sauf 'pas de tumeur' avec confiance < 0.95 (verification requise)
automatique_mask = (max_probs >= SEUIL_HAUTE_CONFIANCE) & ~(
    (codes_pred == "notumor") & (max_probs < 0.95)
)

nb_total = len(y_pred_eval)
nb_auto = int(np.sum(automatique_mask))
nb_revision = nb_total - nb_auto
taux_couverture_auto = (nb_auto / nb_total) * 100

# 2) Accuracy par tranche de confiance
tranches = [
    ("Faible (<0.50)", max_probs < SEUIL_CONFIANCE_FAIBLE),
    ("Moyenne basse [0.50, 0.65)", (max_probs >= SEUIL_CONFIANCE_FAIBLE) & (max_probs < SEUIL_CONFIANCE_MOYENNE)),
    ("Moyenne haute [0.65, 0.85)", (max_probs >= SEUIL_CONFIANCE_MOYENNE) & (max_probs < SEUIL_HAUTE_CONFIANCE)),
    ("Haute (>0.85)", max_probs > SEUIL_HAUTE_CONFIANCE),
]

accuracy_par_tranche = []
for nom_tranche, mask in tranches:
    n = int(np.sum(mask))
    if n > 0:
        acc = float(np.mean(y_pred_eval[mask] == y_true_eval[mask]) * 100)
    else:
        acc = np.nan
    accuracy_par_tranche.append((nom_tranche, n, acc))

mask_haute = max_probs > SEUIL_HAUTE_CONFIANCE
if np.sum(mask_haute) > 0:
    accuracy_haute = float(np.mean(y_pred_eval[mask_haute] == y_true_eval[mask_haute]) * 100)
    critere_haute = accuracy_haute > 95.0
else:
    accuracy_haute = np.nan
    critere_haute = False

# 3) Analyse Cout-Benefice
# Definition metier:
# - FN: tumeur reelle classee 'pas de tumeur'
# - FP: pas de tumeur reelle classee comme tumeur
vrai_tumeur = codes_true != "notumor"
pred_tumeur = codes_pred != "notumor"

FN = int(np.sum(vrai_tumeur & (~pred_tumeur)))
FP = int(np.sum((~vrai_tumeur) & pred_tumeur))

Cout_total = (FN * 1000) + (FP * 100) + (nb_revision * 50)
Cottotal = Cout_total  # Alias selon l'enonce fourni

# Sortie lisible
print("=" * 60)
print("ETAPE 7 - ANALYSE DE PERFORMANCE DU SAD")
print("=" * 60)
print(f"Labels de verite utilises : {source_verite}")

print("\n1) TAUX DE COUVERTURE AUTOMATIQUE")
print("-" * 40)
print(f"Cas automatiques : {nb_auto}/{nb_total}")
print(f"Taux de couverture automatique : {taux_couverture_auto:.2f}%")
print(f"Cas en revision humaine : {nb_revision}")

print("\n2) ACCURACY PAR TRANCHE DE CONFIANCE")
print("-" * 40)
for nom_tranche, n, acc in accuracy_par_tranche:
    if np.isnan(acc):
        print(f"{nom_tranche:<30} | n={n:<4} | accuracy=N/A")
    else:
        print(f"{nom_tranche:<30} | n={n:<4} | accuracy={acc:.2f}%")

if np.isnan(accuracy_haute):
    statut_haute = "N/A (aucun cas > 0.85)"
else:
    statut_haute = "OK" if critere_haute else "ALERTE"
print(f"\nCritere metier (accuracy > 95% si confiance > 0.85) : {statut_haute}")
if not np.isnan(accuracy_haute):
    print(f"Accuracy observee pour confiance > 0.85 : {accuracy_haute:.2f}%")

print("\n3) ANALYSE COUT-BENEFICE")
print("-" * 40)
print(f"FN (cout unitaire 1000) : {FN}")
print(f"FP (cout unitaire 100)  : {FP}")
print(f"Revisions (cout 50)     : {nb_revision}")
print(f"Cout_total = (FN*1000) + (FP*100) + (Revision*50) = {Cout_total}")

# Variables de synthese pour reutilisation ulterieure
metriques_sad = {
    "source_verite": source_verite,
    "nb_total": nb_total,
    "nb_auto": nb_auto,
    "nb_revision": nb_revision,
    "taux_couverture_auto": taux_couverture_auto,
    "accuracy_haute_confiance": accuracy_haute,
    "critere_accuracy_haute": critere_haute,
    "FN": FN,
    "FP": FP,
    "Cout_total": Cout_total,
    "Cottotal": Cottotal,
    "accuracy_par_tranche": accuracy_par_tranche,
}
# Out:
# ...
# ETAPE 7 - ANALYSE DE PERFORMANCE DU SAD
# ...
# Labels de verite utilises : labels_all (pipeline CNN calibre)
#
# 1) TAUX DE COUVERTURE AUTOMATIQUE
# ----------------------------------------
# Cas automatiques : 902/1120
# Taux de couverture automatique : 80.54%
# Cas en revision humaine : 218
#
# 2) ACCURACY PAR TRANCHE DE CONFIANCE
# ----------------------------------------
# Faible (<0.50)                 | n=20   | accuracy=50.00%
# Moyenne basse [0.50, 0.65)     | n=68   | accuracy=66.18%
# Moyenne haute [0.65, 0.85)     | n=114  | accuracy=73.68%
# Haute (>0.85)                  | n=918  | accuracy=95.42%
#
# Critere metier (accuracy > 95% si confiance > 0.85) : OK
# Accuracy observee pour confiance > 0.85 : 95.42%
#
# 3) ANALYSE COUT-BENEFICE
# ----------------------------------------
# FN (cout unitaire 1000) : 12
# FP (cout unitaire 100)  : 7
# Revisions (cout 50)     : 218
# Cout_total = (FN*1000) + (FP*100) + (Revision*50) = 23600

# %%
# ===============================
# ETAPE 7B - OPTIMISATION AUTOMATIQUE DES SEUILS DU SAD
# ===============================

# Alignement de la verite terrain avec les predictions actives
if "labels_all" in globals() and len(labels_all) == len(y_pred):
    y_true_opt = np.asarray(labels_all, dtype=int)
    source_verite_opt = "labels_all (pipeline CNN calibre)"
elif "y_test" in globals() and len(y_test) == len(y_pred):
    y_true_opt = np.asarray(y_test, dtype=int)
    source_verite_opt = "y_test (dataset de test)"
else:
    raise ValueError("Impossible d'aligner les labels de verite pour l'optimisation.")

y_pred_opt = np.asarray(y_pred, dtype=int)
max_probs_opt = np.max(probas, axis=1)
probas_triees = np.sort(probas, axis=1)
margin_top1_top2 = probas_triees[:, -1] - probas_triees[:, -2]

codes_pred_opt = np.array([normaliser_code_classe(class_names[int(idx)]) for idx in y_pred_opt])
codes_true_opt = np.array([normaliser_code_classe(class_names[int(idx)]) for idx in y_true_opt])

vrai_tumeur_opt = codes_true_opt != "notumor"
pred_tumeur_opt = codes_pred_opt != "notumor"


def evaluer_politique_automatique(seuil_tumeur, seuil_notumor, marge_notumor):
    auto_mask = ((pred_tumeur_opt) & (max_probs_opt >= seuil_tumeur)) | (
        (~pred_tumeur_opt) & (max_probs_opt >= seuil_notumor) & (margin_top1_top2 >= marge_notumor)
    )

    nb_total_local = len(auto_mask)
    nb_auto_local = int(np.sum(auto_mask))
    nb_revision_local = nb_total_local - nb_auto_local

    if nb_auto_local > 0:
        accuracy_auto = float(np.mean(y_pred_opt[auto_mask] == y_true_opt[auto_mask]) * 100)
    else:
        accuracy_auto = np.nan

    # Erreurs residuelles uniquement sur les cas auto-validees
    FN_auto = int(np.sum(auto_mask & vrai_tumeur_opt & (~pred_tumeur_opt)))
    FP_auto = int(np.sum(auto_mask & (~vrai_tumeur_opt) & pred_tumeur_opt))

    Cottotal_local = (FN_auto * 1000) + (FP_auto * 100) + (nb_revision_local * 50)

    # Contrainte metier de l'enonce
    mask_haute = max_probs_opt > 0.85
    if np.sum(mask_haute) > 0:
        accuracy_haute = float(np.mean(y_pred_opt[mask_haute] == y_true_opt[mask_haute]) * 100)
    else:
        accuracy_haute = np.nan

    return {
        "seuil_tumeur": float(seuil_tumeur),
        "seuil_notumor": float(seuil_notumor),
        "marge_notumor": float(marge_notumor),
        "nb_auto": nb_auto_local,
        "nb_revision": nb_revision_local,
        "taux_couverture_auto": (nb_auto_local / nb_total_local) * 100,
        "accuracy_auto": accuracy_auto,
        "accuracy_haute": accuracy_haute,
        "critere_haute": (not np.isnan(accuracy_haute)) and (accuracy_haute > 95.0),
        "FN_auto": FN_auto,
        "FP_auto": FP_auto,
        "Cottotal": int(Cottotal_local),
    }


# Reference: regle actuelle du notebook
baseline = evaluer_politique_automatique(
    seuil_tumeur=SEUIL_HAUTE_CONFIANCE,
    seuil_notumor=0.95,
    marge_notumor=0.00,
)

# Grille de recherche
seuils_tumeur = np.round(np.arange(0.75, 0.91, 0.01), 2)
seuils_notumor = np.round(np.arange(0.90, 0.99, 0.01), 2)
marges_notumor = np.round(np.arange(0.00, 0.21, 0.02), 2)

resultats = []
for seuil_tumeur in seuils_tumeur:
    for seuil_notumor in seuils_notumor:
        for marge_notumor in marges_notumor:
            r = evaluer_politique_automatique(seuil_tumeur, seuil_notumor, marge_notumor)
            resultats.append(r)

# Contraintes de securite
candidats = [
    r for r in resultats
    if r["critere_haute"] and r["FN_auto"] <= baseline["FN_auto"]
]

if len(candidats) == 0:
    meilleure_politique = baseline
    mode_selection = "Aucun candidat ne respecte les contraintes: baseline conservee"
else:
    candidats_plus_couverture = [
        r for r in candidats
        if r["taux_couverture_auto"] >= baseline["taux_couverture_auto"]
    ]

    if len(candidats_plus_couverture) > 0:
        meilleure_politique = sorted(
            candidats_plus_couverture,
            key=lambda x: (x["Cottotal"], -x["taux_couverture_auto"], -np.nan_to_num(x["accuracy_auto"], nan=-1.0))
        )[0]
        mode_selection = "Meilleur candidat augmentant (ou maintenant) la couverture"
    else:
        meilleure_politique = sorted(
            candidats,
            key=lambda x: (x["Cottotal"], -x["taux_couverture_auto"], -np.nan_to_num(x["accuracy_auto"], nan=-1.0))
        )[0]
        mode_selection = "Meilleur candidat en cout sous contraintes (couverture non amelioree)"

# Top resultats lisibles
df_resultats = pd.DataFrame(candidats if len(candidats) > 0 else resultats)
df_top = df_resultats.sort_values(
    by=["Cottotal", "taux_couverture_auto", "accuracy_auto"],
    ascending=[True, False, False]
).head(10)

# Variables de seuils optimises (reutilisables ensuite)
SEUIL_TUMEUR_OPT = meilleure_politique["seuil_tumeur"]
SEUIL_NOTUMOR_OPT = meilleure_politique["seuil_notumor"]
MARGE_NOTUMOR_OPT = meilleure_politique["marge_notumor"]

print("=" * 72)
print("OPTIMISATION AUTOMATIQUE DES SEUILS DU SAD")
print("=" * 72)
print(f"Labels utilises: {source_verite_opt}")
print(f"Mode de selection: {mode_selection}")
print("\n--- Baseline (regle actuelle) ---")
print(f"Seuil tumeur = {SEUIL_HAUTE_CONFIANCE:.2f}, Seuil notumor = 0.95, Marge = 0.00")
print(f"Couverture auto : {baseline['taux_couverture_auto']:.2f}%")
print(f"FN_auto={baseline['FN_auto']} | FP_auto={baseline['FP_auto']} | Revisions={baseline['nb_revision']}")
print(f"Cottotal baseline : {baseline['Cottotal']}")

print("\n--- Politique optimisee proposee ---")
print(f"Seuil tumeur = {SEUIL_TUMEUR_OPT:.2f}")
print(f"Seuil notumor = {SEUIL_NOTUMOR_OPT:.2f}")
print(f"Marge top1-top2 notumor = {MARGE_NOTUMOR_OPT:.2f}")
print(f"Couverture auto : {meilleure_politique['taux_couverture_auto']:.2f}%")
print(f"FN_auto={meilleure_politique['FN_auto']} | FP_auto={meilleure_politique['FP_auto']} | Revisions={meilleure_politique['nb_revision']}")
print(f"Cottotal optimise : {meilleure_politique['Cottotal']}")
print(f"Accuracy (>0.85) : {meilleure_politique['accuracy_haute']:.2f}%")

print("\nDelta couverture : "
      f"{meilleure_politique['taux_couverture_auto'] - baseline['taux_couverture_auto']:+.2f} points")
print("Delta Cottotal : "
      f"{meilleure_politique['Cottotal'] - baseline['Cottotal']:+d}")

print("\nTop 10 politiques candidates (tri par Cottotal puis couverture):")
display(df_top.reset_index(drop=True))

optimisation_seuils_sad = {
    "source_verite": source_verite_opt,
    "baseline": baseline,
    "meilleure_politique": meilleure_politique,
    "SEUIL_TUMEUR_OPT": SEUIL_TUMEUR_OPT,
    "SEUIL_NOTUMOR_OPT": SEUIL_NOTUMOR_OPT,
    "MARGE_NOTUMOR_OPT": MARGE_NOTUMOR_OPT,
    "top10": df_top.reset_index(drop=True),
}
# Out:
# ...
# OPTIMISATION AUTOMATIQUE DES SEUILS DU SAD
# ...
# Labels utilises: labels_all (pipeline CNN calibre)
# Mode de selection: Meilleur candidat augmentant (ou maintenant) la couverture
#
# --- Baseline (regle actuelle) ---
# Seuil tumeur = 0.85, Seuil notumor = 0.95, Marge = 0.00
# Couverture auto : 80.54%
# FN_auto=3 | FP_auto=1 | Revisions=218
# Cottotal baseline : 14000
#
# --- Politique optimisee proposee ---
# Seuil tumeur = 0.75
# Seuil notumor = 0.90
# Marge top1-top2 notumor = 0.00
# Couverture auto : 86.88%
# FN_auto=3 | FP_auto=4 | Revisions=147
# Cottotal optimise : 10750
# Accuracy (>0.85) : 95.42%
#
# Delta couverture : +6.34 points
# Delta Cottotal : -3250
#
# Top 10 politiques candidates (tri par Cottotal puis couverture):
#    seuil_tumeur  seuil_notumor  marge_notumor  nb_auto  nb_revision  \
# 0          0.75            0.9           0.00      973          147
# 1          0.75            0.9           0.02      973          147
# ...
